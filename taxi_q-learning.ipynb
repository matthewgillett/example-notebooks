# %% [markdown]
# The code in this notebook is adapted from the "Tutorial: An Introduction to Reinforcement Learning Using OpenAI Gym" post found here: https://www.gocoder.one/blog/rl-tutorial-with-openai-gym/

# %%
import gym
import numpy as np
import random

env = gym.make("Taxi-v3", render_mode='ansi').env

# %%
# Reset environment and print initial state
env.reset()

print(env.render())
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
# Get a random action from environment and print current state
print("Step 1")

action = env.action_space.sample()

env.step(action)

print(env.render())
# Out:
# Step 1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)

# %%
max_steps = 20
for i in range(2, max_steps + 1):
    print(f"Step {i}")

    action = env.action_space.sample()

    env.step(action)
    
    print(env.render())
# Out:
# Step 2
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 3
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 4
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 5
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 6
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 7
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 8
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 9
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 11
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 12
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 13
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 14
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Step 15
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 16
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 17
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 18
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 19
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 20
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)

# %%
steps = 0

info = env.reset()
state = info[0]

done = False
max_steps = 5000
for i in range(1, max_steps + 1):
    action = env.action_space.sample()
    state, reward, done, _, _ = env.step(action)
    steps += 1

    if done:
        break

print(f"Steps taken: {steps}")
# Out:
# Steps taken: 969

# %%
# Initialize q-table
state_size = env.observation_space.n
action_size = env.action_space.n
qtable = np.zeros((state_size, action_size))

# Hyperparameters
learning_rate = 0.5
discount_rate = 0.8
epsilon = 1.0
decay_rate= 0.01

episodes = 2000
max_steps = 300
steps_taken = []

for episode in range(episodes):
    # Reset the environment
    info = env.reset()
    state = info[0]

    for i in range(1, max_steps + 1):
        if random.uniform(0,1) < epsilon:
            # Explore
            action = env.action_space.sample()
        else:
            # Exploit
            action = np.argmax(qtable[state,:])

        # Get new state after action
        new_state, reward, done, _, _ = env.step(action)

        # Update q-table
        qtable[state,action] = qtable[state,action] + learning_rate * (reward + discount_rate * np.max(qtable[new_state,:])-qtable[state,action])

        # Set current state
        state = new_state

        if done:
            steps_taken.append(i)
            break
        elif i == max_steps:
            steps_taken.append(i)

    # Decrease probability of exploration
    epsilon = np.exp(-decay_rate*episode)

print(steps_taken)
# Out:
# [300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 241, 300, 300, 300, 300, 300, 300, 300, 300, 144, 300, 300, 300, 300, 209, 300, 300, 300, 300, 79, 249, 281, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 231, 300, 268, 228, 191, 300, 300, 300, 225, 300, 165, 173, 300, 300, 300, 240, 50, 213, 82, 119, 156, 300, 134, 37, 216, 69, 103, 300, 110, 152, 112, 220, 102, 118, 300, 151, 84, 82, 65, 17, 272, 150, 135, 34, 80, 165, 17, 137, 142, 103, 75, 30, 74, 109, 48, 99, 73, 40, 133, 106, 107, 14, 300, 300, 72, 300, 78, 112, 42, 64, 17, 32, 197, 87, 65, 24, 44, 203, 188, 107, 292, 146, 28, 95, 187, 90, 16, 148, 119, 87, 131, 69, 151, 29, 53, 80, 13, 49, 136, 12, 29, 145, 40, 54, 125, 104, 137, 46, 56, 24, 12, 48, 36
 13, 8, 19, 10, 14, 9, 13, 12, 14, 14, 14, 6, 10, 14, 12, 14, 8, 7, 19, 10, 16, 16, 15, 13, 14, 13, 15, 12, 10, 12, 12, 18, 18, 15, 8, 15, 12, 15, 13, 14, 15, 12, 10, 14, 16, 16, 14, 13, 15, 20, 20, 10, 13, 17, 13, 12, 13, 13, 14, 16, 18, 24, 13, 14, 8, 15, 13, 13, 9, 21, 12, 10, 10, 9, 13, 15, 11, 15, 15, 11, 15, 13, 19, 13, 17, 15, 7, 15, 14, 15, 15, 13, 20, 14, 10, 13, 19, 13, 12, 12, 16, 14, 13, 12, 15, 11, 11, 13, 12, 12, 13, 14, 16, 11, 13, 12, 14, 16, 13, 9, 16, 16, 16, 12, 13, 12, 12, 17, 15, 10, 9, 13, 9, 12, 13, 13, 10, 16, 18, 21, 11, 10, 16, 10, 14, 12, 8, 11, 13, 11, 11, 10, 14, 22, 10, 17, 12, 11, 16, 8, 9, 18, 11, 14, 17, 12, 18, 16, 10, 9, 11, 10, 11, 11, 13, 17, 13, 14, 10, 14, 14, 12, 13, 17, 16, 10, 8, 20, 14, 10, 15, 10, 13, 9, 18, 14, 12, 13, 15, 14, 15, 10, 12, 15, 13, 16, 12, 7, 17, 17, 13, 13, 11, 13, 13, 15, 11, 10, 10, 16, 10, 18, 9, 8, 10, 16, 9, 11, 12, 11, 16, 14, 13, 14, 15, 15, 21, 12, 16, 15, 17, 13, 15, 16, 15, 9, 15, 14, 16, 18, 13, 10, 10, 10, 17, 16, 15, 11, 14, 12, 13, 8, 14, 13, 13, 13, 16, 11, 12, 14, 11, 12, 14, 13, 13, 16, 13, 15, 13, 7, 10, 15, 12, 17, 14, 14, 11, 16, 11, 13, 11, 14, 12, 24, 10, 27, 12, 13, 12, 17, 16, 17, 13, 11, 10, 17, 15, 13, 15, 18, 14, 15, 14, 17, 15, 11, 16, 14, 12, 14, 13, 14, 15, 15, 15, 7, 11, 10, 12, 16, 16, 14, 12, 7, 15, 14, 14, 12, 13, 9, 17, 17, 10, 15, 16, 14, 11, 13, 23, 9, 10, 15, 15, 16, 15, 13, 15, 9, 17, 13, 9, 17, 13, 18, 13, 13, 10, 12, 14, 12, 10, 15 ...

# %%
steps = 0

info = env.reset()
state = info[0]

done = False
max_steps = 100
for i in range(1, max_steps + 1):
    action = np.argmax(qtable[state,:])
    state, reward, done, _, _ = env.step(action)
    print(f"Step {i}")
    print(env.render())
    steps += 1

    if done:
        break

print(f"Steps taken: {steps}")
env.close()
# Out:
# Step 1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 2
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 3
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
#
# Step 4
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 5
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
#
# Step 6
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 7
# +---------+
# |R: | : :G|
# | :_| : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 8
# +---------+
# |R: | : :G|
# | : | : : |
# | :_: : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# Step 9
# +---------+
# |R: | : :G|
# | : | : : |
# | : :_: : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 10
# +---------+
# |R: | : :G|
# | : |_: : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 11
# +---------+
# |R: |_: :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
#
# Step 12
# +---------+
# |R: | :_:G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 13
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
#
# Step 14
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Steps taken: 14
